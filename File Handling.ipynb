# %%
# handle file using Python

# %%
# file:- set of documents, information collect, file

# file:- textual- .txt
# Binary File:- .xlsx, .exe, etc

# %%
# Read,copy,delete,new file create , update,

# %%
# file handling in Python

# %% [markdown]
# # Textual File
#     user can read and understand the content or information
#     no such huge or any external software required
#     all textual file can be opened in notepad, and user can understand
#     ex:- .py, .java, .html, allProgramming_lang, .csv
#
#
#
#
# # Binary File
#     user can not read and understand the content or information
#     without external software we can not even open file
#     all textual file can be opened in notepad, and user can not understand
#     Binary in format:- Bytes
#
#     Example:- zip file, jpeg,jpg, png,src, dll, exe, .xlsx, mp3, mp4, rar, pdf

# %%
file = open(r"C:\Users\Lenovo\Desktop\employee.csv",mode = 'r')
all_lines = file.read()

print(all_lines.upper())
# Out:
# EMPLOYEE_ID,EMPLOYEE_NAME,SALARY,ADDRESS,DEPT,DESIGNATION
# 1,"MOHAN VERMA",87876,NOIDA,IT,"DATA ANALYST"
# 2,"KARAN VERMA",97876,"GR NOIDA",IT,"MIS EXECUTIVE"
# 3,"MOHAN SHARMA",97606,DELHI,HR,HR
# 4,"RAVI KHANNA",87878,FARIDABAD,ADMIN,"SR ADMIN"
# 5,"AJAY VERMA",99876,DELHI,IT,"DATABASE ENGINEER"

# %%
file.close()
print('Done')
# Out:
# Done

# %%
file = open(r"C:\Users\Lenovo\Desktop\employee.csv",mode = 'r')
all_lines = file.read(10)

print(all_lines.upper())
file.close()
# Out:
# EMPLOYEE_I

# %%
f = open('shivam.py')

all_data = f.read()

f.close()

# %%
print(all_data)
# Out:
# def factorial(number):
#     '''This is UDF'''
#     if number>=0:
#         res = 1
#
#         for i in range(1,number+1):
#             res*= i
#         return res
#     else:
#         print('Not allowed!!')
#
#
# # anagram:- two words with same count of characters
#
# # Cheater = teacher
# def check_anagram(w1,w2):
#     '''To check anagram'''
#
#     w1,w2 = w1.lower(),w2.lower()
#
#     w1_counts = {}
#     w2_counts = {}
#
#
#     for i in w1:
#         w1_counts[i] = w1.count(i)
#
#     for j in w2:
#         w2_counts[j] = w2.count(j)
#
#
#
#     return 'Anagram' if w1_counts == w2_counts else 'Not an Anagram'
#
#
# def check_armstrong(number):
#     lt = len(str(number))
#
#     ans = 0
#
#     for i in str(number):
#         ans += int(i)**lt
#
#     return 'Armstrong Number' if ans == number else 'Not an Armstrong Number'
#
# def give_prime_number(n1,n2):
#     all_prime = []
#
#     for i in range(n1,n2+1):
#
#         for j in range(2,i):
#             if i % j == 0:
# ...

# %%
def factorial(number):
    '''This is UDF'''
    if number>=0:
        res = 1

        for i in range(1,number+1):
            res*= i
        return res
    else:
        print('Not allowed!!')

# %%
factorial(12)
# Out:
# 479001600

# %%
# write/create a new file

# %%
f = open('harsh.txt',mode = 'w')
f.write('This is Python Class\n')
f.write('We are in TV')
f.close()
print('done')
# Out:
# done

# %%
# copy:- 

f = open('harsh.txt')
data = f.read()
f.close()

f = open(r"C:\Users\Lenovo\Desktop\harsh_copy.txt",'w')

f.write(data)
f.close()
print('done')
# Out:
# done

# %%
for i in range(1,101):

    f = open(f"C:\\Users\\Lenovo\\Desktop\\harsh_copy_{i}.txt",'w')

    f.write(data)
    f.close()
print('done')
# Out:
# done

# %%
import os

# %%
for i in os.listdir(r'C:\\Users\\Lenovo\\Desktop'):
    if 'harsh_copy' in i:
        os.remove(f'C:\\Users\\Lenovo\\Desktop\\{i}')
print('done')
# Out:
# done

# %%
# read, write, copy, delete

# %%
f = open('harsh.txt',mode = 'w')
f.write('Java is an Awesome Programming Language\n')
f.write('This is Data Analytics class')
f.close()
print('done')

# truncate existing data
# Out:
# done

# %%
# mode;- x

# %%
f = open('harsh.txt',mode = 'x')
f.write('Java is an Awesome Programming Language\n')
f.write('This is Data Analytics class')
f.close()
print('done')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 f = open('harsh.txt',mode = 'x')
#       2 f.write('Java is an Awesome Programming Language\n')
#       3 f.write('This is Data Analytics class')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'harsh.txt'

# %%
# mode:-a

# %%
f = open('harsh.txt',mode = 'a')
f.write('\nThis is a New Line1\n')
f.write('New Line 2')
f.close()
print('done')

# truncate existing data
# Out:
# done

# %%
# mode:- r, w, x, a

# %%
f = open('harsh.txt',mode = 'w+')
f.write('This is a Python Class')
f.seek(0)

data = f.read()
print('This is data: ',data)
f.close()
print('done')

# truncate existing data
# Out:
# This is data:  This is a Python Class
# done

# %%
f = open('harsh.txt',mode = 'r+')

data = f.read()

f.write('\nThis is a Java Class')


print('This is data: ',data)
f.close()
print('done')

# truncate existing data
# Out:
# This is data:  This is a Python Class
# done

# %%
# mode:- 
# r, w, x, a
# r+, w+, x+, a+

# %%
# task:- html

# %% [markdown]
# # Binary File Handling

# %%
f = open(r"C:\Users\Lenovo\Desktop\virat_bhai.webp",'rb')
data = f.read()
f.close()

print(data)
# Out:
# b'RIFF@"\x01\x00WEBPVP8X\n\x00\x00\x000\x00\x00\x00\xff\x03\x00\xff\x03\x00ICCPH\x0c\x00\x00\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\x00\x00\
# ...

# %%
type(data)
# Out:
# bytes

# %%
f = open(r"C:\Users\Lenovo\Desktop\virat_bhai_ka_copy.webp",'wb')
f.write(data)
f.close()
print('done')
# Out:
# done

# %%
# mode:- wb+, rb+, xb+, ab+, wb, rb, xb, ab

# %%
# mode:- 
# r, w, x, a
# r+, w+, x+, a+

# %%
# open()

# %%
import requests as r

# %%
url = '''https://static.toiimg.com/thumb/resizemode-4,width-1280,height-720,msid-111741230/111741230.jpg'''

# %%
print(url)
# Out:
# https://static.toiimg.com/thumb/resizemode-4,width-1280,height-720,msid-111741230/111741230.jpg

# %%
data = r.get(url).content
type(data)
# Out:
# bytes

# %%
f = open(r"C:\Users\Lenovo\Desktop\rohitsharma.jpg",'wb')

f.write(data)
f.close()

print('done')
# Out:
# done

# %%
# context manager

# %%
with open(r"C:\Users\Lenovo\Desktop\rohitsharma_copy.jpg",'wb') as f:
    f.write(data)

# %%
import requests as r
def give_image(url,file_name):
    bytes_data = r.get(url).content
    
    with open(f"C:\\Users\\Lenovo\\Desktop\\Random_images\\{file_name}.jpg", 'wb') as f:
        f.write(bytes_data)

# %%
ur = '''https://picsum.photos/2000/1200'''
for i in range(11,31):
    give_image(ur,i)
    
print('done')
# Out:
# done

# %%
os.remove(r"C:\Users\Lenovo\Desktop\rohitsharma_copy.jpg")
